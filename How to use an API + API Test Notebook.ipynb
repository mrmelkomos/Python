# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-07-13T09:49:00.148Z', 'error_code': 0, 'error_message': None, 'elapsed': 176, 'credit_count': 1, 'notice': None, 'total_count': 9991}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11597, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11597
# 1    1027     Ethereum    ETH      ethereum              9130
# 2     825  Tether USDt   USDT        tether             91500
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20935
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11597
# 1    1027     Ethereum    ETH      ethereum              9130
# 2     825  Tether USDt   USDT        tether             91501
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20935
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    #To append to df:
    
    #df2 = pd.json_normalize(data['data'])
    #df2['timestamp'] = pd.to_datetime('now')
    #df_append = pd.DataFrame(df2)
    #df = pd.concat([df,df_append])


    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df


    if not os.path.isfile(r'C:\Users\mrmel\OneDrive\Documents\Data Analysis Bootcamp\Python\How to use an API + API Test Notebook\API.CSV'):
        df.to_csv(r'C:\Users\mrmel\OneDrive\Documents\Data Analysis Bootcamp\Python\How to use an API + API Test Notebook\API.CSV', header='column_names')
    else:
        df.to_csv(r'C:\Users\mrmel\OneDrive\Documents\Data Analysis Bootcamp\Python\How to use an API + API Test Notebook\API.CSV', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\mrmel\OneDrive\Documents\Data Analysis Bootcamp\Python\How to use an API + API Test Notebook\API.CSV')
df72
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             11597
# 1            1   1027     Ethereum    ETH      ethereum              9130
# 2            2    825  Tether USDt   USDT        tether             91501
# 3            3   1839          BNB    BNB           bnb              2192
# 4            4   5426       Solana    SOL        solana               701
# 5            5   3408         USDC   USDC      usd-coin             20935
# 6            6     52          XRP    XRP           xrp              1352
# 7            7  11419      Toncoin    TON       toncoin               458
# 8            8     74     Dogecoin   DOGE      dogecoin              1021
# 9            9   2010      Cardano    ADA       cardano              1210
# 10          10   1958         TRON    TRX          tron               999
# 11          11   5805    Avalanche   AVAX     avalanche               751
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11597
# 1    1027     Ethereum    ETH      ethereum              9130
# 2     825  Tether USDt   USDT        tether             91501
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20935
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11597
# 1    1027     Ethereum    ETH      ethereum              9130
# 2     825  Tether USDt   USDT        tether             91501
# 3    1839          BNB    BNB           bnb              2192
# 4    5426       Solana    SOL        solana               701
# 5    3408         USDC   USDC      usd-coin             20935
# 6      52          XRP    XRP           xrp              1352
# 7   11419      Toncoin    TON       toncoin               458
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               751
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          1.18730                       3.04773
# Ethereum                         1.16279                       3.51109
# Tether USDt                      0.00346                       0.02655
# BNB                              0.67657                       3.76147
# Solana                           1.47872                       4.51944
# USDC                             0.00583                       0.00794
# XRP                              0.44131                      11.17506
# Toncoin                          0.45843                       0.64153
# Dogecoin                         1.07394                       4.34480
# Cardano                          0.32613                       5.69725
# TRON                             0.19062                       2.97968
# Avalanche                        1.14396                       4.87205
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      1.18730
#              quote.USD.percent_change_24h     3.04773
#              quote.USD.percent_change_7d      3.45930
#              quote.USD.percent_change_30d   -12.94000
#              quote.USD.percent_change_60d    -4.97287
#              quote.USD.percent_change_90d    -8.72211
# Ethereum     quote.USD.percent_change_1h      1.16279
#              quote.USD.percent_change_24h     3.51109
#              quote.USD.percent_change_7d      5.59106
#              quote.USD.percent_change_30d    -9.20505
#              quote.USD.percent_change_60d     8.83893
#              quote.USD.percent_change_90d     3.97238
# Tether USDt  quote.USD.percent_change_1h      0.00346
#              quote.USD.percent_change_24h     0.02655
#              quote.USD.percent_change_7d      0.04671
#              quote.USD.percent_change_30d     0.03964
#              quote.USD.percent_change_60d     0.07375
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    1.18730
#             quote.USD.percent_change_24h   3.04773
#             quote.USD.percent_change_7d    3.45930
#             quote.USD.percent_change_30d -12.94000
#             quote.USD.percent_change_60d  -4.97287
#             quote.USD.percent_change_90d  -8.72211
# Ethereum    quote.USD.percent_change_1h    1.16279
#             quote.USD.percent_change_24h   3.51109
#             quote.USD.percent_change_7d    5.59106
#             quote.USD.percent_change_30d  -9.20505
#             quote.USD.percent_change_60d   8.83893
#             quote.USD.percent_change_90d   3.97238
# Tether USDt quote.USD.percent_change_1h    0.00346
#             quote.USD.percent_change_24h   0.02655
#             quote.USD.percent_change_7d    0.04671
#             quote.USD.percent_change_30d   0.03964
#             quote.USD.percent_change_60d   0.07375
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   1.18730
# 1       Bitcoin  quote.USD.percent_change_24h   3.04773
# 2       Bitcoin   quote.USD.percent_change_7d   3.45930
# 3       Bitcoin  quote.USD.percent_change_30d -12.94000
# 4       Bitcoin  quote.USD.percent_change_60d  -4.97287
# 5       Bitcoin  quote.USD.percent_change_90d  -8.72211
# 6      Ethereum   quote.USD.percent_change_1h   1.16279
# 7      Ethereum  quote.USD.percent_change_24h   3.51109
# 8      Ethereum   quote.USD.percent_change_7d   5.59106
# 9      Ethereum  quote.USD.percent_change_30d  -9.20505
# 10     Ethereum  quote.USD.percent_change_60d   8.83893
# 11     Ethereum  quote.USD.percent_change_90d   3.97238
# 12  Tether USDt   quote.USD.percent_change_1h   0.00346
# 13  Tether USDt  quote.USD.percent_change_24h   0.02655
# 14  Tether USDt   quote.USD.percent_change_7d   0.04671
# 15  Tether USDt  quote.USD.percent_change_30d   0.03964
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   1.18730
# 1       Bitcoin  quote.USD.percent_change_24h   3.04773
# 2       Bitcoin   quote.USD.percent_change_7d   3.45930
# 3       Bitcoin  quote.USD.percent_change_30d -12.94000
# 4       Bitcoin  quote.USD.percent_change_60d  -4.97287
# 5       Bitcoin  quote.USD.percent_change_90d  -8.72211
# 6      Ethereum   quote.USD.percent_change_1h   1.16279
# 7      Ethereum  quote.USD.percent_change_24h   3.51109
# 8      Ethereum   quote.USD.percent_change_7d   5.59106
# 9      Ethereum  quote.USD.percent_change_30d  -9.20505
# 10     Ethereum  quote.USD.percent_change_60d   8.83893
# 11     Ethereum  quote.USD.percent_change_90d   3.97238
# 12  Tether USDt   quote.USD.percent_change_1h   0.00346
# 13  Tether USDt  quote.USD.percent_change_24h   0.02655
# 14  Tether USDt   quote.USD.percent_change_7d   0.04671
# 15  Tether USDt  quote.USD.percent_change_30d   0.03964
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   1.18730
# 1       Bitcoin            24h   3.04773
# 2       Bitcoin             7d   3.45930
# 3       Bitcoin            30d -12.94000
# 4       Bitcoin            60d  -4.97287
# 5       Bitcoin            90d  -8.72211
# 6      Ethereum             1h   1.16279
# 7      Ethereum            24h   3.51109
# 8      Ethereum             7d   5.59106
# 9      Ethereum            30d  -9.20505
# 10     Ethereum            60d   8.83893
# 11     Ethereum            90d   3.97238
# 12  Tether USDt             1h   0.00346
# 13  Tether USDt            24h   0.02655
# 14  Tether USDt             7d   0.04671
# 15  Tether USDt            30d   0.03964
# 16  Tether USDt            60d   0.07375
# 17  Tether USDt            90d  -0.00978
# 18          BNB             1h   0.67657
# 19          BNB            24h   3.76147
# 20          BNB             7d   5.80414
# 21          BNB            30d -10.96040
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df72[['name', 'quote.USD.price', 'timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      58664.77693  2024-07-13 20:00:20.189719
# 15  Bitcoin      58681.18116  2024-07-13 20:02:13.163093
# 30  Bitcoin      58687.15768  2024-07-13 20:03:14.293901

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data=df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
